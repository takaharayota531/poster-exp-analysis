# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import shapiro

# Load and clean the data
file_path = '無題のフォーム（回答） - シート1 (1).csv'
data = pd.read_csv(file_path)
data.columns = data.columns.str.strip().str.replace('\n', '').str.replace(' ', '')

# Extract relevant columns
data_cleaned = data[['実験手順', '実験番号', 'どれくらい酔ったか？', 'どれくらいターゲットを取得するのが大変だったか？',
                     'どれくらい視野外物体の区別をするのが難しかったか？', '精神的にしんどかったですか？', 'どれくらい体験として楽しかったか？']]

data_cleaned.columns = ['Condition', 'Experiment', 'Dizziness', 'Target Difficulty', 'Object Distinction Difficulty', 
                        'Mental Strain', 'Fun Experience']

# Get unique experiment numbers
experiment_numbers = data_cleaned['Experiment'].unique()
# print(experiment_numbers)

# Metrics for evaluation
metrics = ['Dizziness', 'Target Difficulty', 'Object Distinction Difficulty', 'Mental Strain', 'Fun Experience']

# Shapiro-Wilk test for normality
shapiro_results = []
for experiment in experiment_numbers:
    experiment_data = data_cleaned[data_cleaned['Experiment'] == experiment]
    for metric in metrics:
        sound_on = experiment_data[experiment_data['Condition'] == '音あり'][metric].dropna()
        sound_off = experiment_data[experiment_data['Condition'] == '音無し'][metric].dropna()

    
        # print(sound_on)
        # print(sound_off)
        # Perform Shapiro-Wilk test
        stat_on, p_on = shapiro(sound_on)
        stat_off, p_off = shapiro(sound_off)

        # Store results
        shapiro_results.append({
            'Experiment': experiment,
            'Metric': metric,
            'Condition': '音あり',
            'W-Statistic': stat_on,
            'p-Value': p_on
        })
        shapiro_results.append({
            'Experiment': experiment,
            'Metric': metric,
            'Condition': '音無し',
            'W-Statistic': stat_off,
            'p-Value': p_off
        })

# Convert results to a DataFrame
shapiro_results_df = pd.DataFrame(shapiro_results)
# 正規性の検定結果をCSVファイルとして保存
output_file = 'shapiro_wilk_results-all1.csv'
shapiro_results_df.to_csv(output_file, index=False)

print(shapiro_results_df)
print(f"Shapiro-Wilk検定結果が {output_file} に保存されました。")


# Output the results for inspection
# import ace_tools as tools; tools.display_dataframe_to_user(name="Shapiro-Wilk Test Results", dataframe=shapiro_results_df)
# Out:
#    Experiment                         Metric Condition  W-Statistic   p-Value
# 0         実験1                      Dizziness       音あり     0.888865  0.194229
# 1         実験1                      Dizziness       音無し     0.658188  0.000460
# 2         実験1              Target Difficulty       音あり     0.824893  0.039127
# 3         実験1              Target Difficulty       音無し     0.872822  0.131798
# 4         実験1  Object Distinction Difficulty       音あり     0.825491  0.039738
# 5         実験1  Object Distinction Difficulty       音無し     0.901253  0.259348
# 6         実験1                  Mental Strain       音あり     0.785310  0.013862
# 7         実験1                  Mental Strain       音無し     0.864730  0.107903
# 8         実験1                 Fun Experience       音あり     0.913067  0.337937
# 9         実験1                 Fun Experience       音無し     0.931358  0.494388
# 10        実験2                      Dizziness       音あり     0.636924  0.000259
# 11        実験2                      Dizziness       音無し     0.636924  0.000259
# 12        実験2              Target Difficulty       音あり     0.815772  0.030865
# 13        実験2              Target Difficulty       音無し     0.932951  0.509946
# 14        実験2  Object Distinction Difficulty       音あり     0.850608  0.075679
# 15        実験2  Object Distinction Difficulty       音無し     0.865508  0.110010
# 16        実験2                  Mental Strain       音あり     0.916548  0.364427
# 17        実験2                  Mental Strain       音無し     0.900553  0.255221
# 18        実験2                 Fun Experience       音あり     0.812592  0.028407
# 19        実験2                 Fun Experience       音無し     0.853290  0.080991
# 20        実験3                      Dizziness       音あり     0.617278  0.000153
# 21        実験3                      Dizziness       音無し     0.805403  0.023534
# 22        実験3              Target Difficulty       音あり     0.856710  0.088284
# 23        実験3              Target Difficulty       音無し     0.880530  0.159050
# 24        実験3  Object Distinction Difficulty       音あり     0.780526  0.012213
# 25        実験3  Object Distinction Difficulty       音無し     0.862775  0.102771
# 26        実験3                  Mental Strain       音あり     0.951013  0.701189
# 27        実験3                  Mental Strain       音無し     0.971350  0.906023
# 28        実験3                 Fun Experience       音あり     0.920461  0.396069
# 29        実験3                 Fun Experience       音無し     0.931358  0.494388
# Shapiro-Wilk検定結果が shapiro_wilk_results-all1.csv に保存されました。

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import shapiro

# Load and clean the data
file_path = '無題のフォーム（回答） - シート1 (1).csv'
data = pd.read_csv(file_path)
data.columns = data.columns.str.strip().str.replace('\n', '').str.replace(' ', '')

# Extract relevant columns
data_cleaned = data[['実験手順', '実験番号', 'どれくらい酔ったか？', 'どれくらいターゲットを取得するのが大変だったか？',
                     'どれくらい視野外物体の区別をするのが難しかったか？', '精神的にしんどかったですか？', 'どれくらい体験として楽しかったか？']]

data_cleaned.columns = ['Condition', 'Experiment', 'Dizziness', 'Target Difficulty', 'Object Distinction Difficulty', 
                        'Mental Strain', 'Fun Experience']

# Get unique experiment numbers
experiment_numbers = data_cleaned['Experiment'].unique()
# print(experiment_numbers)

# Metrics for evaluation
metrics = ['Dizziness', 'Target Difficulty', 'Object Distinction Difficulty', 'Mental Strain', 'Fun Experience']

# Shapiro-Wilk test for normality
shapiro_results = []
for experiment in experiment_numbers:
    experiment_data = data_cleaned[data_cleaned['Experiment'] == experiment]
    for metric in metrics:
        sound_on = experiment_data[experiment_data['Condition'] == '音あり'][metric].dropna()
        sound_off = experiment_data[experiment_data['Condition'] == '音無し'][metric].dropna()

    
        # print(sound_on)
        # print(sound_off)
        # Perform Shapiro-Wilk test
        stat_on, p_on = shapiro(sound_on)
        stat_off, p_off = shapiro(sound_off)

        # Store results
        shapiro_results.append({
            'Experiment': experiment,
            'Metric': metric,
            'Condition': 'Sound',
            'W-Statistic': stat_on,
            'p-Value': p_on
        })
        shapiro_results.append({
            'Experiment': experiment,
            'Metric': metric,
            'Condition': 'No Sound',
            'W-Statistic': stat_off,
            'p-Value': p_off
        })

# Convert results to a DataFrame
shapiro_results_df = pd.DataFrame(shapiro_results)
# 正規性の検定結果をCSVファイルとして保存
output_file = 'shapiro_wilk_results-all1.csv'
shapiro_results_df.to_csv(output_file, index=False)

print(shapiro_results_df)
print(f"Shapiro-Wilk検定結果が {output_file} に保存されました。")


# Output the results for inspection
# import ace_tools as tools; tools.display_dataframe_to_user(name="Shapiro-Wilk Test Results", dataframe=shapiro_results_df)
# Out:
#    Experiment                         Metric Condition  W-Statistic   p-Value
# 0         実験1                      Dizziness     Sound     0.888865  0.194229
# 1         実験1                      Dizziness  No Sound     0.658188  0.000460
# 2         実験1              Target Difficulty     Sound     0.824893  0.039127
# 3         実験1              Target Difficulty  No Sound     0.872822  0.131798
# 4         実験1  Object Distinction Difficulty     Sound     0.825491  0.039738
# 5         実験1  Object Distinction Difficulty  No Sound     0.901253  0.259348
# 6         実験1                  Mental Strain     Sound     0.785310  0.013862
# 7         実験1                  Mental Strain  No Sound     0.864730  0.107903
# 8         実験1                 Fun Experience     Sound     0.913067  0.337937
# 9         実験1                 Fun Experience  No Sound     0.931358  0.494388
# 10        実験2                      Dizziness     Sound     0.636924  0.000259
# 11        実験2                      Dizziness  No Sound     0.636924  0.000259
# 12        実験2              Target Difficulty     Sound     0.815772  0.030865
# 13        実験2              Target Difficulty  No Sound     0.932951  0.509946
# 14        実験2  Object Distinction Difficulty     Sound     0.850608  0.075679
# 15        実験2  Object Distinction Difficulty  No Sound     0.865508  0.110010
# 16        実験2                  Mental Strain     Sound     0.916548  0.364427
# 17        実験2                  Mental Strain  No Sound     0.900553  0.255221
# 18        実験2                 Fun Experience     Sound     0.812592  0.028407
# 19        実験2                 Fun Experience  No Sound     0.853290  0.080991
# 20        実験3                      Dizziness     Sound     0.617278  0.000153
# 21        実験3                      Dizziness  No Sound     0.805403  0.023534
# 22        実験3              Target Difficulty     Sound     0.856710  0.088284
# 23        実験3              Target Difficulty  No Sound     0.880530  0.159050
# 24        実験3  Object Distinction Difficulty     Sound     0.780526  0.012213
# 25        実験3  Object Distinction Difficulty  No Sound     0.862775  0.102771
# 26        実験3                  Mental Strain     Sound     0.951013  0.701189
# 27        実験3                  Mental Strain  No Sound     0.971350  0.906023
# 28        実験3                 Fun Experience     Sound     0.920461  0.396069
# 29        実験3                 Fun Experience  No Sound     0.931358  0.494388
# Shapiro-Wilk検定結果が shapiro_wilk_results-all1.csv に保存されました。
