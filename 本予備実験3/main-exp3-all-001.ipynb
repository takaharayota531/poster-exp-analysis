# %%
import pandas as pd
import os
import numpy as np

# %%
def calculate_values(df,subject_name,method):
    # データ範囲を取得
    data = df.values
    # print(data)
    # 結果を出力する
    results=[]
    place_value=0  
    place_values=[[0.25, -0.1, -0.025],
                    [0.25, -0.1, 0.075],
                    [0.25, -0.1, 0.175],
                    [0.25, 0.0, -0.025],
                    [0.25, 0.0, 0.075],
                    [0.25, 0.0, 0.175],
                    [0.25, 0.1, -0.025],
                    [0.25, 0.1, 0.075],
                    [0.25, 0.1, 0.175],
                    [0.35, -0.1, -0.025],
                    [0.35, -0.1, 0.075],
                    [0.35, -0.1, 0.175],
                    [0.35, 0.0, -0.025],
                    [0.35, 0.0, 0.075],
                    [0.35, 0.0, 0.175],
                    [0.35, 0.1, -0.025],
                    [0.35, 0.1, 0.075],
                    [0.35, 0.1, 0.175],
                    [0.45, -0.1, -0.025],
                    [0.45, -0.1, 0.075],
                    [0.45, -0.1, 0.175],
                    [0.45, 0.0, -0.025],
                    [0.45, 0.0, 0.075],
                    [0.45, 0.0, 0.175],
                    [0.45, 0.1, -0.025],
                    [0.45, 0.1, 0.075],
                    [0.45, 0.1, 0.175]]
    # print(data)
    for i in range(len(data)):
        if isinstance(data[i][0],str) and data[i][0].startswith("place index:"):
            place_text,place_value=data[i][0].split(":")
            place_value=int(place_value)
            row_count=0
        else:
            x_error= abs(float(data[i][0])-place_values[place_value][0])
            y_error= abs(float(data[i][1])-place_values[place_value][1])
            z_error=abs(float(data[i][2])-place_values[place_value][2])
            squared_error=np.sqrt(x_error**2+y_error**2+z_error**2)
            results.append([
                subject_name,
                method,
                place_value,
               x_error,
              y_error,
              z_error,
              squared_error
                ])
            row_count+=1
    return results

# %%
# .txtファイルからデータを読み込む
def read_txt_to_dataframe(file_path):
    # ファイルを読み込み、各行をリストに格納
    with open(file_path, 'r', encoding='utf-8-sig') as file:
        lines = file.readlines()

    # 各行をカンマで分割してデータフレームに変換
    data = [line.strip().split(',') for line in lines]

    # データフレームに変換
    df = pd.DataFrame(data)
    return df

# %%
import pathlib
import datetime
# 全てのフォルダを処理し、結果を統合
all_results = []
def calculate_all_folders(files_paths,subject_name):
    for i, file_path in enumerate(files_paths):
            method=i-1
            print(i-1,file_path)
            # order=sorted_indices.index(i-1)
            df = read_txt_to_dataframe(file_path)
            # all_results.extend(calculate_values_averages(df,subject_name, method,order))
            all_results.extend(calculate_values(df,subject_name, method))
            
            # all_results.extend(calculate_values_median(df,subject_name, method,order))

# %%
import os
from datetime import datetime

# ファイルの作成日時を取得する関数
def get_creation_time(file_name):
    return os.path.getctime(file_name)

# %%
subject_names=["河合","菊池","竹村","廣野里奈","水上","佐々木","小谷","岡本","島川","ほうさん","村上","平岡","浦西","歩さん","伊藤","朴さん"]
# subject_names=["竹村"]


for i in range(len(subject_names)):
        root_path = r"C:\Users\takaharayota\Research\Semi-Exp3\01Length\{}".format(subject_names[i])
        files_paths = [
                root_path + r"\Dense_0.1.txt",
                root_path + r"\Sparse_0.1.txt",
                root_path + r"\NoSound_0.1.txt",
        
        ]

        # # ファイル名と元のインデックスのタプルのリストを作成
        # indexed_files = list(enumerate(files_paths))
        # # 作成日時順に並べ替える
        # sorted_indexed_files = sorted(indexed_files, key=lambda x: get_creation_time(x[1]))
        # # 並べ替え後のインデックスを抽出
        # sorted_indices = [index-1 for index, file in sorted_indexed_files]
        calculate_all_folders(files_paths,subject_names[i])
    
print(all_results)  


# 統合されたデータをデータフレームに変換
columns = ['Subject','Method', 'Place', 'X', 'Y', 'Z','Sum_Squared_Error']
df_all = pd.DataFrame(all_results, columns=columns)

# データの表示
# DataFrameを.txtファイルに出力
df_all.to_csv('output.txt', sep='\t', index=False)

print("DataFrameの内容がoutput.txtに出力されました。")
# Out:
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\河合\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\河合\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\河合\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\菊池\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\菊池\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\菊池\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\竹村\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\竹村\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\竹村\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\廣野里奈\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\廣野里奈\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\廣野里奈\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\水上\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\水上\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\水上\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\佐々木\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\佐々木\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\佐々木\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\小谷\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\小谷\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\小谷\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\岡本\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\岡本\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\岡本\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\島川\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\島川\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\島川\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\ほうさん\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\ほうさん\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\ほうさん\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\村上\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\村上\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\村上\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\平岡\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\平岡\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\平岡\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\浦西\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\浦西\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\浦西\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\歩さん\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\歩さん\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\歩さん\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\伊藤\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\伊藤\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\伊藤\NoSound_0.1.txt
# -1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\朴さん\Dense_0.1.txt
# 0 C:\Users\takaharayota\Research\Semi-Exp3\01Length\朴さん\Sparse_0.1.txt
# 1 C:\Users\takaharayota\Research\Semi-Exp3\01Length\朴さん\NoSound_0.1.txt
# [['河合', -1, 18, 0.024096300000000015, 0.019560300000000003, 0.03890838, np.float64(0.0497704635703185)], ['河合', -1, 15, 0.016564400000000035, 0.024988490000000002, 0.008959250000000002, np.float64(0.0312901284817209)], ['河合', -1, 2, 0.0003737999999999797, 0.01948570000000001, 0.20482438, np.float64(0.20574950515934273)], ['河合', -1, 18, 0.005367399999999967, 0.0009081100000000036, 0.020224968000000003, np.float64(0.020944760135487916)], ['河合', -1, 2, 0.2283252, 0.009197200000000003, 0.016600700000000024, np.float64(0.2291125677115291)], ['河合', -1, 4, 0.01464299999999999, 0.01732602, 0.007968649999999994, np.float64(0.024043872418204593)], ['河合', -1, 15, 0.004914600000000047, 0.021737610000000004, 0.023160485, np.float64(0.03214164039229059)], ['河合', -1, 8, 0.029308600000000018, 0.0232864, 0.01356389999999999, np.float64(0.039814944959524944)], ['河合', -1, 22, 0.013523699999999972, 0.001918569, 0.0803059, np.float64(0.08145924713320005)], ['河合', -1, 14, 0.012402600000000041, 0.005397327, 0.0006851000000000218, np.float64(0.013543448139780728)], ['河合', -1, 17, 0.023929000000000034, 0.051113500000000006, 0.005516700000000013, np.float64(0.05670644497885582)], ['河合', -1, 19, 0.039928799999999987, 0.014152220000000007, 0.1060397, np.float64(0.11418849493910671)], ['河合', -1, 23, 0.04448469999999999, 0.01932154, 0.022240500000000024, np.float64(0.05335588329614271)], ['河合', -1, 4, 0.0038640999999999814, 0.0163388, 0.004983009999999996, np.float64(0.017513367549106592)], ['河合', -1, 11, 0.030864800000000026, 0.01294228, 0.03628379999999998, np.float64(0.04936246178097684)], ['河合', -1, 23, 0.025287100000000007, 0.005661219, 0.008452700000000007, np.float64(0.02725683334993193)], ['河合', -1, 20, 0.021670999999999996, 0.013071040000000006, 0.0336978, np.float64(0.04214292410976723)], ['河合', -1, 10, 0.09498329999999999, 0.041717620000000004, 0.0062514200000000075, np.float64(0.10392914581276419)], ['河合', -1, 25, 0.019204799999999966, 0.036078700000000005, 0.007956390000000008, np.float64(0.0416389370488981)], ['河合', -1, 2, 0.02155760000000001, 0.025043199999999988, 0.009966099999999978, np.float64(0.03451398460349079)], ['河合', -1, 17, 0.057344000000000006, 0.036477560000000006, 0.00014040000000001274, np.float64(0.06796297839054437)], ['河合', -1, 7, 0.031520099999999995, 0.011815690000000004, 0.008385549999999992, np.float64(0.03469070023779571)], ['河合', -1, 16, 0.035179000000000016, 0.025722170000000003, 0.01145512, np.float64(0.045060091485962406)], ['河合', -1, 14, 0.005452400000000024, 0.01744708, 0.03628329999999999, np.float64(0.04062766453017451)], ['河合', -1, 1, 0.003806099999999979, 0.026582190000000006, 0.009091269999999999, np.float64(0.02835049228177529)], ['河合', -1, 20, 0.0089611, 0.022485099999999994, 0.0406088, np.float64(0.047275317795441626)], ['河合', -1, 10, 0.011992900000000029, 0.019788299999999995, 0.061692800000000006, np.float64(0.06588936210906887)], ['河合', -1, 20, 0.011272000000000004, 0.01199829999999999, 0.03541999999999998, np.float64(0.03905884774145288)], ['河合', -1, 21, 0.012206400000000006, 0.01123621, 0.04508596, np.float64(0.04804156955435262)], ['河合', -1, 13, 0.005962999999999996, 0.01104201, 0.013711969999999997, np.float64(0.018587669975577894)], ['河合', 0, 11, 0.0031463000000000463, 0.007095690000000002, 0.019904699999999997, np.float64(0.021364575875876875)], ['河合', 0, 18, 0.0009637000000000118, 0.0072761999999999966, 0.021366699999999995, np.float64(0.022592203810606875)], ['河合', 0, 26, 0.007856399999999986, 0.008768120000000004, 0.10396093, np.float64(0.10462541715930837)], ['河合', 0, 9, 0.0028567000000000453, 0.005956299999999998, 0.08716979999999999, np.float64(0.08741974763530262)], ['河合', 0, 8, 0.01211290000000001, 0.0016965999999999926, 0.029915899999999995, np.float64(0.03231968240530837)], ['河合', 0, 24, 0.00039759999999999796, 0.0077149400000000035, 0.07717515999999999, np.float64(0.07756083873959331)], ['河合', 0, 22, 0.0125247, 0.005616292, 0.009719820000000004, np.float64(0.016819207673123726)], ['河合', ...
# DataFrameの内容がoutput.txtに出力されました。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib



place_labels ={0: '(0.250, -0.100, -0.025)',
 1: '(0.250, -0.100, 0.075)',
 2: '(0.250, -0.100, 0.175)',
 3: '(0.250, 0.000, -0.025)',
 4: '(0.250, 0.000, 0.075)',
 5: '(0.250, 0.000, 0.175)',
 6: '(0.250, 0.100, -0.025)',
 7: '(0.250, 0.100, 0.075)',
 8: '(0.250, 0.100, 0.175)',
 9: '(0.350, -0.100, -0.025)',
 10: '(0.350, -0.100, 0.075)',
 11: '(0.350, -0.100, 0.175)',
 12: '(0.350, 0.000, -0.025)',
 13: '(0.350, 0.000, 0.075)',
 14: '(0.350, 0.000, 0.175)',
 15: '(0.350, 0.100, -0.025)',
 16: '(0.350, 0.100, 0.075)',
 17: '(0.350, 0.100, 0.175)',
 18: '(0.450, -0.100, -0.025)',
 19: '(0.450, -0.100, 0.075)',
 20: '(0.450, -0.100, 0.175)',
 21: '(0.450, 0.000, -0.025)',
 22: '(0.450, 0.000, 0.075)',
 23: '(0.450, 0.000, 0.175)',
 24: '(0.450, 0.100, -0.025)',
 25: '(0.450, 0.100, 0.075)',
 26: '(0.450, 0.100, 0.175)'}


# MethodとPlaceの具体的な意味をラベルに追加
method_labels = {
    -1: 'Dense',
    0: 'Sparse',
    1: 'NoSound',
}

df_all['Method_Label'] = df_all['Method'].map(method_labels)
df_all['Place_Label'] = df_all['Place'].map(place_labels)

df_all['X'] = df_all['X'] * 100
df_all['Y'] = df_all['Y'] * 100
df_all['Z'] = df_all['Z'] * 100

# Placeごとの中央値を計算 (数値列のみ対象)
numeric_columns = ['X', 'Y', 'Z']
df_median = df_all.groupby(['Place', 'Method'])[numeric_columns].median().reset_index()


# Methodのラベルを追加
df_median['Method_Label'] = df_median['Method'].map(method_labels)
# df_mean['Method_Label'] = df_mean['Method'].map(method_labels)

# 中央値プロット
for axis in ['X', 'Y', 'Z']:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Method_Label', y=axis, data=df_median)
    plt.title(f'{axis} 軸における各手法の中央値結果')
    plt.xlabel('sonification手法')
    plt.ylabel('(cm)')
    plt.tight_layout()
    plt.show()


# 可視化
plt.figure(figsize=(12, 6))
sns.boxplot(x='Place_Label', y='X', hue='Method_Label', data=df_all)
plt.title('x軸(定位)における各手法と位置による誤差')
plt.xlabel('各座標位置')
plt.ylabel('(cm)')
plt.legend(title='sonification手法', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Place_Label', y='Y', hue='Method_Label', data=df_all)
plt.title('y軸(周波数)における各手法と位置による誤差')
plt.xlabel('各座標位置')
plt.ylabel('(cm)')
plt.legend(title='sonification手法', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Place_Label', y='Z', hue='Method_Label', data=df_all)
plt.title('z軸(振幅)における各手法と位置による誤差')
plt.xlabel('各座標位置')
plt.ylabel('(cm)')
plt.legend(title='sonification手法', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import japanize_matplotlib

# 二乗平方和の列を追加
df_all['Sum_Squared_Error'] = np.sqrt(df_all['X']**2 + df_all['Y']**2 + df_all['Z']**2)

# ラベルの並び順を定義（必要な順序に合わせて変更してください）
method_order = ["Dense", "Sparse", "NoSound"]

df_median_sse_method = df_all.groupby(['Place','Method'])['Sum_Squared_Error'].median().reset_index()
df_median_sse_method['Method_Label'] = df_median_sse_method['Method'].map(method_labels)

# カテゴリ型で順序付けする
df_median_sse_method['Method_Label'] = pd.Categorical(df_median_sse_method['Method_Label'],
                                                      categories=method_order,
                                                      ordered=True)

# Method_Label順に並び替え
df_median_sse_method = df_median_sse_method.sort_values(['Method_Label', 'Place', 'Method'])

# 並び替えた後にCSV出力
df_median_sse_method.to_csv('median-sse-method.txt', sep='\t', index=False)


# Methodごとの二乗平方和のボックスプロットを作成
plt.figure(figsize=(12, 6))
sns.boxplot(x='Method_Label', y='Sum_Squared_Error', data=df_median_sse_method)
plt.title('各sonification手法における二乗平方和の分布')
plt.xlabel('sonification手法')
plt.ylabel('二乗平方和 (cm)')
plt.tight_layout()
plt.show()

# Placeごとの二乗平方和の分布を可視化
plt.figure(figsize=(14, 8))
sns.boxplot(x='Place_Label', y='Sum_Squared_Error', hue='Method_Label', data=df_all)
plt.title('各座標位置における各手法の二乗平方和の分布')
plt.xlabel('各座標位置')
plt.ylabel('二乗平方和 (cm)')
plt.legend(title='sonification手法', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from itertools import combinations
import numpy as np
import scipy.stats as stats

# Wilcoxonの符号付順位検定
wilcoxon_results = []
methods = df_all['Method_Label'].unique()
num_comparisons = sum(1 for _ in combinations(methods, 2))


for method1, method2 in combinations(methods, 2):
    stat, p_value = stats.wilcoxon(df_all[df_all['Method_Label'] == method1]['Sum_Squared_Error'],
                                    df_all[df_all['Method_Label'] == method2]['Sum_Squared_Error'])
    wilcoxon_results.append({
        'Comparison': f'{method1} vs {method2}',
        'stat': stat,
        'p_value': p_value
    })

# 結果をデータフレームに変換
df_wilcoxon_results = pd.DataFrame(wilcoxon_results)

# ボンフェローニ補正
df_wilcoxon_results['p_value_bonferroni'] = df_wilcoxon_results['p_value'] * num_comparisons
df_wilcoxon_results['p_value_bonferroni'] = df_wilcoxon_results['p_value_bonferroni'].apply(lambda x: min(x, 1.0))

# 有意性の判断
df_wilcoxon_results['significant'] = df_wilcoxon_results['p_value_bonferroni'] < 0.05

# ボンフェローニ補正結果をCSVファイルとして保存
output_file_bonferroni = 'wilcoxon_bonferroni_results.csv'
df_wilcoxon_results.to_csv(output_file_bonferroni, index=False)

print(f"Wilcoxonの符号付順位検定結果（ボンフェローニ補正適用）が {output_file_bonferroni} に保存されました。")

# 結果の一部を表示
df_wilcoxon_results
# Out:
# Wilcoxonの符号付順位検定結果（ボンフェローニ補正適用）が wilcoxon_bonferroni_results.csv に保存されました。
#           Comparison     stat       p_value  p_value_bonferroni  significant
# 0    Dense vs Sparse  44297.0  1.011541e-05        3.034624e-05         True
# 1   Dense vs NoSound  15026.0  8.669181e-45        2.600754e-44         True
# 2  Sparse vs NoSound  32114.0  3.715062e-17        1.114519e-16         True
